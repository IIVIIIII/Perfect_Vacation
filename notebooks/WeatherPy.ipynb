# %% [markdown]
# # WeatherPy

# %%
# dependencies and setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
import time
import scipy.stats as st
from scipy.stats import linregress
import os
import csv

# import API key
from config import weather_api_key

# incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# list for holding lat_lngs and cities
lat_lngs = []
cities = []

# create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # if the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# print the city count to confirm sufficient count
len(cities)
# Out:
# 605

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it's being processed.

# %%
# create query url
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# create lists to hold desired data
names = []
hemis = []
latis = []
longis = []
temps = []
humids = []
clouds = []
winds = []

# iterate through list of cities and append desired data to corresponding lists
for city in cities:
    
    response = requests.get(query_url + city).json()
    
    try:
        print(json.dumps(response, indent=4, sort_keys=True))
        names.append(response["name"])
        if response["coord"]["lat"] >= 0:
            hemis.append("northern")
        else:
            hemis.append("southern")
        latis.append(response["coord"]["lat"])
        longis.append(response["coord"]["lon"])
        temps.append(response["main"]["temp"])
        humids.append(response["main"]["humidity"])
        clouds.append(response["clouds"]["all"])
        winds.append(response["wind"]["speed"])
        
    except:
        print("We dont got that")
        pass
# Out:
# {
#     "base": "stations",
#     "clouds": {
#         "all": 11
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -14.25,
#         "lon": 129.55
#     },
#     "dt": 1624906725,
#     "id": 2063039,
#     "main": {
#         "feels_like": 64.92,
#         "grnd_level": 1011,
#         "humidity": 48,
#         "pressure": 1014,
#         "sea_level": 1014,
#         "temp": 66.33,
#         "temp_max": 66.33,
#         "temp_min": 66.33
#     },
#     "name": "Port Keats",
#     "sys": {
#         "country": "AU",
#         "sunrise": 1624916783,
#         "sunset": 1624957427
#     },
#     "timezone": 34200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02n",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 122,
#         "gust": 18.57,
#         "speed": 8.57
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 35.3029,
#         "lon": 37.1841
#     },
#     "dt": 1624906726,
#     "id": 172515,
#     "main": {
#         "feels_like": 83.07,
#         "grnd_level": 961,
#         "humidity": 33,
#         "pressure": 1007,
#         "sea_level": 1007,
#         "temp": 84.83,
#         "temp_max": 84.83,
#         "temp_min": 84.83
#     },
#     "name": "Abu Samrah",
#     "sys": {
#         "country": "SY",
#         "sunrise": 1624846728,
#         "sunset": 1624899000
#     },
#     "timezone": 10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 252,
#         "gust": 15.97,
#         "speed": 9.95
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -33.0117,
#         "lon": 17.9442
#     },
#     "dt": 1624906726,
#     "id": 3361934,
#     "main": {
#         "feels_like": 50.88,
#         "grnd_level": 1011,
#         "humidity": 88,
#         "pressure": 1015,
#         "sea_level": 1015,
#         "temp": 51.85,
#         "temp_max": 51.85,
#         "temp_min": 51.85
#     },
#     "name": "Saldanha",
#     "rain": {
#         "1h": 0.84
#     },
#     "sys": {
#         "country": "ZA",
#         "id": 1943,
#         "sunrise": 1624859508,
#         "sunset": 1624895457,
#         "type": 1
#     },
#     "timezone": 7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10n",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 117,
#         "gust": 11.97,
#         "speed": 8.7
#     }
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# We dont got that
# {
#     "cod": "404",
#     "message": "city not found"
# }
# We dont got that
# {
#     "base": "stations",
#     "clouds": {
#         "all": 16
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 13.9835,
#         "lon": 10.2704
#     },
#     "dt": 1624906727,
#     "id": 2444219,
#     "main": {
#         "feels_like": 86.99,
#         "grnd_level": 960,
#         "humidity": 41,
#         "pressure": 1009,
#         "sea_level": 1009,
#         "temp": 87.1,
#         "temp_max": 87.1,
#         "temp_min": 87.1
#     },
#     "name": "Gour\u00e9",
#     "sys": {
#         "country": "NE",
#         "sunrise": 1624856024,
#         "sunset": 1624902625
#     },
#     "timezone": 3600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02n",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 250,
#         "gust": 15.5,
#         "speed": 11.99
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 60.8156,
#         "lon": -115.7999
#     },
#     "dt": 1624906519,
#     "id": 5972762,
#     "main": {
#         "feels_like": 67.3,
#         "humidity": 60,
#         "pressure": 1018,
#         "temp": 67.98,
#         "temp_max": 69.76,
#         "temp_min": 67.98
#     },
#     "name": "Hay River",
#     "sys": {
#         "country": "CA",
#         "id": 1036,
#         "sunrise": 1624875195,
#         "sunset": 1624943976,
#         "type": 1
#     },
#     "timezone": -21600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 20,
#         "speed": 8.05
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -21.4803,
#         "lon": -56.1381
#     },
#     "dt": 1624906728,
#     "id": 3460087,
#     "main": {
#         "feels_like": 42.19,
#         "grnd_level": 998,
#         "humidity": 77,
#         "pressure": 1029,
#         "sea_level": 1029,
#         "temp": 46.44,
#         "temp_max": 46.44,
#         "temp_min": 46.44
#     },
#     "name": "Jardim",
#     "sys": {
#         "country": "BR",
#         "sunrise": 1624875766,
#         "sunset": 1624914763
#     },
#     "timezone": -14400,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 196,
#         "gust": 22.1,
#         "speed": 8.57
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -21.2,
#         "lon": -175.2
#     },
#     "dt": 1624906728,
#     "id": 4032243,
#     "main": {
#         "feels_like": 74.28,
#         "humidity": 78,
#         "pressure": 1019,
#         "temp": 73.56,
#         "temp_max": 73.56,
#         "temp_min": 73.56
#     },
#     "name": "Vaini",
#     "sys": {
#         "country": "TO",
#         "id": 7285,
#         "sunrise": 1624990715,
#         "sunset": 1625029794,
#         "type": 1
#     },
#     "timezone": 46800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 90,
#         "speed": 6.91
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 90
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 65.9667,
#         "lon": 78.3667
#     },
#     "dt": 1624906729,
#     "id": 1488414,
#     "main": {
#         "feels_like": 41.79,
#         "grnd_level": 1007,
#         "humidity": 55,
#         "pressure": 1009,
#         "sea_level": 1009,
#         "temp": 47.28,
#         "temp_max": 47.28,
#         "temp_min": 47.28
#     },
#     "name": "Urengoy",
#     "sys": {
#         "country": "RU",
#         "sunrise": 0,
#         "sunset": 0
#     },
#     "timezone": 18000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 297,
#         "gust": 18.54,
#         "speed": 12.68
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 6
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 42.097,
#         "lon": -79.2353
#     },
#     "dt": 1624906728,
#     "id": 5122534,
#     "main": {
#         "feels_like": 95.36,
#         "grnd_level": 977,
#         "humidity": 76,
#         "pressure": 1022,
#         "sea_level": 1022,
#         "temp": 85.1,
#         "temp_max": 89.1,
#         "temp_min": 77.85
#     },
#     "name": "Jamestown",
#     "sys": {
#         "country": "US",
#         "id": 2019701,
#         "sunrise": 1624873406,
#         "sunset": 1624928212,
#         "type": 2
#     },
#     "timezone": -14400,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 256,
#         "gust": 14.56,
#         "speed": 10.67
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 8
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -13.0333,
#         "lon": 33.4833
#     },
#     "dt": 1624906729,
#     "id": 928534,
#     "main": {
#         "feels_like": 57.36,
#         "grnd_level": 903,
#         "humidity": 57,
#         "pressure": 1021,
#         "sea_level": 1021,
#         "temp": 59.07,
#         "temp_max": 59.07,
#         "temp_min": 59.07
#     },
#     "name": "Kasungu",
#     "sys": {
#         "country": "MW",
#         "sunrise": 1624853301,
#         "sunset": 1624894205
#     },
#     "timezone": 7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 95,
#         "gust": 3.27,
#         "speed": 3.15
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 62.456,
#         "lon": -114.3525
#     },
#     "dt": 1624906730,
#     "id": 6185377,
#     "main": {
#         "feels_like": 72.95,
#         "humidity": 43,
#         "pressure": 1013,
#         "temp": 73.85,
#         "temp_max": 75.33,
#         "temp_min": 71.56
#     },
#     "name": "Yellowknife",
#     "sys": {
#         "country": "CA",
#         "id": 19346,
#         "sunrise": 1624873455,
#         "sunset": 1624945021,
#         "type": 2
#     },
#     "timezone": -21600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02d",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 329,
#         "gust": 10,
#         "speed": 5.99
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 28
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 22.0752,
#         "lon": -159.319
#     },
#     "dt": 1624906730,
#     "id": 5848280,
#     "main": {
#         "feels_like": 83.98,
#         "humidity": 77,
#         "pressure": 1016,
#         "temp": 80.08,
#         "temp_max": 82.38,
#         "temp_min": 79.2
#     },
#     "name": "Kapaa",
#     "sys": {
#         "country": "US",
#         "id": 2001562,
#         "sunrise": 1624895785,
#         "sunset": 1624944277,
#         "type": 2
#     },
#     "timezone": -36000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03d",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 46,
#         "gust": 7,
#         "speed": 1.99
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 6
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -37.6167,
#         "lon": -73.65
#     },
#     "dt": 1624906731,
#     "id": 3883457,
#     "main": {
#         "feels_like": 48.79,
#         "grnd_level": 1018,
#         "humidity": 48,
#         "pressure": 1022,
#         "sea_level": 1022,
#         "temp": 51.67,
#         "temp_max": 51.67,
#         "temp_min": 51.67
#     },
#     "name": "Lebu",
#     "sys": {
#         "country": "CL",
#         "sunrise": 1624882221,
#         "sunset": 1624916715
#     },
#     "timezone": -14400,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 233,
#         "gust": 2.93,
#         "speed": 2.84
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -53.15,
#         "lon": -70.9167
#     },
#     "dt": 1624906721,
#     "id": 3874787,
#     "main": {
#         "feels_like": 42.78,
#         "humidity": 61,
#         "pressure": 1020,
#         "temp": 48.31,
#         "temp_max": 48.31,
#         "temp_min": 48.11
#     },
#     "name": "Punta Arenas",
#     "sys": {
#         "country": "CL",
#         "id": 8487,
#         "sunrise": 1624885175,
#         "sunset": 1624912449,
#         "type": 1
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02d",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 260,
#         "speed": 13.8
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 76
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -0.7393,
#         "lon": -90.3518
#     },
#     "dt": 1624906731,
#     "id": 3652764,
#     "main": {
#         "feels_like": 75.85,
#         "humidity": 88,
#         "pressure": 1012,
#         "temp": 74.55,
#         "temp_max": 78.76,
#         "temp_min": 74.55
#     },
#     "name": "Puerto Ayora",
#     "sys": {
#         "country": "EC",
#         "id": 2005652,
#         "sunrise": 1624881736,
#         "sunset": 1624925218,
#         "type": 2
#     },
#     "timezone": -21600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 155,
#         "gust": 14,
#         "speed": 5.99
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 67.4667,
#         "lon": 86.5833
#     },
#     "dt": 1624906732,
#     "id": 1505991,
#     "main": {
#         "feels_like": 42.01,
#         "grnd_level": 1001,
#         "humidity": 97,
#         "pressure": 1003,
#         "sea_level": 1003,
#         "temp": 45.7,
#         "temp_max": 45.7,
#         "temp_min": 45.7
#     },
#     "name": "Igarka",
#     "sys": {
#         "country": "RU",
#         "sunrise": 0,
#         "sunset": 0
#     },
#     "timezone": 25200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 174,
#         "gust": 10.67,
#         "speed": 7
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 28
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 42.2506,
#         "lon": -75.833
#     },
#     "dt": 1624906733,
#     "id": 5110365,
#     "main": {
#         "feels_like": 100.15,
#         "humidity": 57,
#         "pressure": 1001,
#         "temp": 90.93,
#         "temp_max": 94.69,
#         "temp_min": 86.5
#     },
#     "name": "Broome",
#     "sys": {
#         "country": "US",
#         "id": 2036074,
#         "sunrise": 1624872557,
#         "sunset": 1624927428,
#         "type": 2
#     },
#     "timezone": -14400,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03d",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 224,
#         "gust": 5.99,
#         "speed": 3
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -33.0153,
#         "lon": 27.9116
#     },
#     "dt": 1624906733,
#     "id": 1006984,
#     "main": {
#         "feels_like": 59.25,
#         "humidity": 77,
#         "pressure": 1012,
#         "temp": 59.94,
#         "temp_max": 59.94,
#         "temp_min": 59.94
#     },
#     "name": "East London",
#     "sys": {
#         "country": "ZA",
#         "id": 1912,
#         "sunrise": 1624857117,
#         "sunset": 1624893064,
#         "type": 1
#     },
#     "timezone": 7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 250,
#         "speed": 17.27
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 40
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -42.8794,
#         "lon": 147.3294
#     },
#     "dt": 1624906734,
#     "id": 2163355,
#     "main": {
#         "feels_like": 38.61,
#         "humidity": 96,
#         "pressure": 1030,
#         "temp": 38.61,
#         "temp_max": 40.26,
#         "temp_min": 36.01
#     },
#     "name": "Hobart",
#     "sys": {
#         "country": "AU",
#         "id": 2002195,
#         "sunrise": 1624916557,
#         "sunset": 1624949118,
#         "type": 2
#     },
#     "timezone": 36000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03n",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 0,
#         "gust": 1.01,
#         "speed": 1.01
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -23.1203,
#         "lon": -134.9692
#     },
#     "dt": 1624906734,
#     "id": 4030556,
#     "main": {
#         "feels_like": 75.29,
#         "grnd_level": 1019,
#         "humidity": 73,
#         "pressure": 1021,
#         "sea_level": 1021,
#         "temp": 74.7,
#         "temp_max": 74.7,
#         "temp_min": 74.7
#     },
#     "name": "Rikitea",
#     "sys": {
#         "country": "PF",
#         "sunrise": 1624894884,
#         "sunset": 1624933489
#     },
#     "timezone": -32400,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 66,
#         "gust": 7.7,
#         "speed": 8.57
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 39
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -46.1927,
#         "lon": 168.8643
#     },
#     "dt": 1624906734,
#     "id": 6201424,
#     "main": {
#         "feels_like": 38.35,
#         "grnd_level": 1019,
#         "humidity": 80,
#         "pressure": 1025,
#         "sea_level": 1025,
#         "temp": 42.48,
#         "temp_max": 42.48,
#         "temp_min": 42.48
#     },
#     "name": "Mataura",
#     "sys": {
#         "country": "NZ",
#         "id": 2008959,
#         "sunrise": 1624912104,
#         "sunset": 1624943233,
#         "type": 2
#     },
#     "timezone": 43200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03n",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 250,
#         "gust": 24.79,
#         "speed": 6.58
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 47.5673,
#         "lon": -122.6326
#     },
#     "dt": 1624906735,
#     "id": 5788054,
#     "main": {
#         "feels_like": 111.51,
#         "humidity": 47,
#         "pressure": 1007,
#         "temp": 98.91,
#         "temp_max": 111.24,
#         "temp_min": 88.68
#     },
#     "name": "Bremerton",
#     "sys": {
#         "country": "US",
#         "id": 2011426,
#         "sunrise": 1624882530,
#         "sunset": 1624939921,
#         "type": 2
#     },
#     "timezone": -25200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 270,
#         "gust": 4,
#         "speed": 4
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 64
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -8.7676,
#         "lon": 160.7034
#     },
#     "dt": 1624906735,
#     "id": 2109701,
#     "main": {
#         "feels_like": 76.17,
#         "grnd_level": 1004,
#         "humidity": 89,
#         "pressure": 1012,
#         "sea_level": 1012,
#         "temp": 74.8,
#         "temp_max": 74.8,
#         "temp_min": 74.8
#     },
#     "name": "Auki",
#     "sys": {
#         "country": "SB",
#         "sunrise": 1624908719,
#         "sunset": 1624950536
#     },
#     "timezone": 39600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 82,
#         "gust": 5.95,
#         "speed": 5.17
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -33.918,
#         "lon": 25.5701
#     },
#     "dt": 1624906736,
#     "id": 964420,
#     "main": {
#         "feels_like": 58.77,
#         "humidity": 82,
#         "pressure": 1011,
#         "temp": 59.29,
#         "temp_max": 59.29,
#         "temp_min": 58.1
#     },
#     "name": "Port Elizabeth",
#     "sys": {
#         "country": "ZA",
#         "id": 1973,
#         "sunrise": 1624857815,
#         "sunset": 1624893490,
#         "type": 1
#     },
#     "timezone": 7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 250,
#         "speed": 19.57
#     }
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# We dont got that
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -21.2078,
#         "lon": -159.775
#     },
#     "dt": 1624906619,
#     "id": 4035715,
#     "main": {
#         "feels_like": 71.53,
#         "humidity": 64,
#         "pressure": 1019,
#         "temp": 71.65,
#         "temp_max": 71.65,
#         "temp_min": 71.65
#     },
#     "name": "Avarua",
#     "sys": {
#         "country": "CK",
#         "id": 7271,
#         "sunrise": 1624900608,
#         "sunset": 1624939674,
#         "type": 1
#     },
#     "timezone": -36000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 120,
#         "speed": 8.05
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 23
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 12.2188,
#         "lon": 125.4808
#     },
#     "dt": 1624906737,
#     "id": 1731248,
#     "main": {
#         "feels_like": 79.36,
#         "grnd_level": 1008,
#         "humidity": 91,
#         "pressure": 1010,
#         "sea_level": 1010,
#         "temp": 77.61,
#         "temp_max": 77.61,
#         "temp_min": 77.61
#     },
#     "name": "Alugan",
#     "sys": {
#         "country": "PH",
#         "sunrise": 1624914978,
#         "sunset": 1624961185
#     },
#     "timezone": 28800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02n",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 227,
#         "gust": 5.88,
#         "speed": 4.81
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 5
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -22.116,
#         "lon": 14.2845
#     },
#     "dt": 1624906737,
#     "id": 3356832,
#     "main": {
#         "feels_like": 58.01,
#         "grnd_level": 1012,
#         "humidity": 76,
#         "pressure": 1015,
#         "sea_level": 1015,
#         "temp": 58.86,
#         "temp_max": 58.86,
#         "temp_min": 58.86
#     },
#     "name": "Henties Bay",
#     "sys": {
#         "country": "NA",
#         "id": 2012545,
#         "sunrise": 1624858939,
#         "sunset": 1624897783,
#         "type": 2
#     },
#     "timezone": 7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 153,
#         "gust": 4.03,
#         "speed": 3.91
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 90
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 47.6666,
#         "lon": -52.7314
#     },
#     "dt": 1624906738,
#     "id": 6167817,
#     "main": {
#         "feels_like": 60.57,
#         "humidity": 97,
#         "pressure": 1010,
#         "temp": 60.28,
#         "temp_max": 62.76,
#         "temp_min": 58.15
#     },
#     "name": "Torbay",
#     "rain": {
#         "1h": 0.51
#     },
#     "sys": {
#         "country": "CA",
#         "id": 998,
#         "sunrise": 1624865721,
#         "sunset": 1624923173,
#         "type": 1
#     },
#     "timezone": -9000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "light intensity drizzle",
#             "icon": "09d",
#             "id": 300,
#             "main": "Drizzle"
#         },
#         {
#             "description": "light rain",
#             "icon": "10d",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 280,
#         "gust": 23.02,
#         "speed": 16.11
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 4
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -42.7826,
#         "lon": 147.0587
#     },
#     "dt": 1624906738,
#     "id": 2155415,
#     "main": {
#         "feels_like": 38.62,
#         "humidity": 89,
#         "pressure": 1030,
#         "temp": 38.62,
#         "temp_max": 39.9,
#         "temp_min": 35.65
#     },
#     "name": "New Norfolk",
#     "sys": {
#         "country": "AU",
#         "id": 2031307,
#         "sunrise": 1624916602,
#         "sunset": 1624949203,
#         "type": 2
#     },
#     "timezone": 36000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 298,
#         "gust": 2.33,
#         "speed": 2.66
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 90
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -13.7,
#         "lon": -76.2167
#     },
#     "dt": 1624906738,
#     "id": 3932145,
#     "main": {
#         "feels_like": 63.03,
#         "humidity": 94,
#         "pressure": 1016,
#         "temp": 62.65,
#         "temp_max": 63.01,
#         "temp_min": 62.65
#     },
#     "name": "Pisco",
#     "sys": {
#         "country": "PE",
#         "id": 8691,
#         "sunrise": 1624879703,
#         "sunset": 1624920465,
#         "type": 1
#     },
#     "timezone": -18000,
#     "visibility": 2000,
#     "weather": [
#         {
#             "description": "mist",
#             "icon": "50d",
#             "id": 701,
#             "main": "Mist"
#         }
#     ],
#     "wind": {
#         "deg": 260,
#         "speed": 4.61
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 18
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 1.8681,
#         "lon": 103.1124
#     },
#     "dt": 1624906739,
#     "id": 1732698,
#     "main": {
#         "feels_like": 78.69,
#         "grnd_level": 1009,
#         "humidity": 84,
#         "pressure": 1010,
#         "sea_level": 1010,
#         "temp": 77.31,
#         "temp_max": 77.31,
#         "temp_min": 77.29
#     },
#     "name": "Parit Raja",
#     "sys": {
#         "country": "MY",
#         "id": 9435,
#         "sunrise": 1624921441,
#         "sunset": 1624965460,
#         "type": 1
#     },
#     "timezone": 28800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02n",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 100,
#         "gust": 2.62,
#         "speed": 2.3
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 77
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 10.6167,
#         "lon": 104.1833
#     },
#     "dt": 1624906445,
#     "id": 1831112,
#     "main": {
#         "feels_like": 91.98,
#         "grnd_level": 1008,
#         "humidity": 87,
#         "pressure": 1009,
#         "sea_level": 1009,
#         "temp": 82.45,
#         "temp_max": 82.45,
#         "temp_min": 82.45
#     },
#     "name": "Kampot",
#     "sys": {
#         "country": "KH",
#         "id": 9312,
#         "sunrise": 1624920265,
#         "sunset": 1624966123,
#         "type": 1
#     },
#     "timezone": 25200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 278,
#         "gust": 8.52,
#         "speed": 6.06
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 13.2167,
#         "lon": -59.5167
#     },
#     "dt": 1624906740,
#     "id": 3374083,
#     "main": {
#         "feels_like": 93.78,
#         "humidity": 55,
#         "pressure": 1015,
#         "temp": 88.41,
#         "temp_max": 88.41,
#         "temp_min": 88.41
#     },
#     "name": "Bathsheba",
#     "sys": {
#         "country": "BB",
#         "id": 8772,
#         "sunrise": 1624872861,
#         "sunset": 1624919290,
#         "type": 1
#     },
#     "timezone": -14400,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02d",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 90,
#         "speed": 25.32
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 54.675,
#         "lon": 20.1347
#     },
#     "dt": 1624906741,
#     "id": 485660,
#     "main": {
#         "feels_like": 68.65,
#         "grnd_level": 1015,
#         "humidity": 87,
#         "pressure": 1015,
#         "sea_level": 1015,
#         "temp": 68.05,
#         "temp_max": 68.05,
#         "temp_min": 68.05
#     },
#     "name": "Tsimmerbude",
#     "sys": {
#         "country": "RU",
#         "id": 8934,
#         "sunrise": 1624845911,
#         "sunset": 1624908003,
#         "type": 1
#     },
#     "timezone": 7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 349,
#         "gust": 4.59,
#         "speed": 4.38
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -3.8004,
#         "lon": 102.2655
#     },
#     "dt": 1624906741,
#     "id": 1649150,
#     "main": {
#         "feels_like": 75.88,
#         "grnd_level": 1009,
#         "humidity": 92,
#         "pressure": 1011,
#         "sea_level": 1011,
#         "temp": 74.43,
#         "temp_max": 74.43,
#         "temp_min": 74.43
#     },
#     "name": "Bengkulu",
#     "sys": {
#         "country": "ID",
#         "sunrise": 1624922229,
#         "sunset": 1624965079
#     },
#     "timezone": 25200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 11,
#         "gust": 5.5,
#         "speed": 4.43
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 98
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 77.484,
#         "lon": -69.3632
#     },
#     "dt": 1624906742,
#     "id": 3831208,
#     "main": {
#         "feels_like": 33.91,
#         "grnd_level": 994,
#         "humidity": 82,
#         "pressure": 998,
#         "sea_level": 998,
#         "temp": 38.08,
#         "temp_max": 38.08,
#         "temp_min": 38.08
#     },
#     "name": "Qaanaaq",
#     "sys": {
#         "country": "GL",
#         "sunrise": 0,
#         "sunset": 0
#     },
#     "timezone": -10800,
#     "visibility": 1278,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 232,
#         "gust": 5.14,
#         "speed": 5.41
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -34.5322,
#         "lon": 20.0403
#     },
#     "dt": 1624906544,
#     "id": 1015776,
#     "main": {
#         "feels_like": 47.66,
#         "humidity": 87,
#         "pressure": 1013,
#         "temp": 49.32,
#         "temp_max": 49.32,
#         "temp_min": 45.28
#     },
#     "name": "Bredasdorp",
#     "sys": {
#         "country": "ZA",
#         "id": 1966,
#         "sunrise": 1624859236,
#         "sunset": 1624894723,
#         "type": 1
#     },
#     "timezone": 7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 20,
#         "speed": 4.61
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 97
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 55.8214,
#         "lon": 65.5842
#     },
#     "dt": 1624906742,
#     "id": 1510421,
#     "main": {
#         "feels_like": 63.75,
#         "grnd_level": 1007,
#         "humidity": 69,
#         "pressure": 1015,
#         "sea_level": 1015,
#         "temp": 64.36,
#         "temp_max": 64.36,
#         "temp_min": 64.36
#     },
#     "name": "Beloz\u00ebrskoye",
#     "sys": {
#         "country": "RU",
#         "sunrise": 1624834505,
#         "sunset": 1624897589
#     },
#     "timezone": 18000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 190,
#         "gust": 6.17,
#         "speed": 5.7
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 71.9167,
#         "lon": 114.0833
#     },
#     "dt": 1624906743,
#     "id": 2017155,
#     "main": {
#         "feels_like": 34.39,
#         "grnd_level": 1013,
#         "humidity": 71,
#         "pressure": 1014,
#         "sea_level": 1014,
#         "temp": 40.73,
#         "temp_max": 40.73,
#         "temp_min": 40.73
#     },
#     "name": "Saskylakh",
#     "sys": {
#         "country": "RU",
#         "sunrise": 0,
#         "sunset": 0
#     },
#     "timezone": 32400,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 94,
#         "gust": 12.01,
#         "speed": 10.38
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -33.65,
#         "lon": 115.3333
#     },
#     "dt": 1624906743,
#     "id": 2075265,
#     "main": {
#         "feels_like": 51.76,
#         "grnd_level": 1010,
#         "humidity": 79,
#         "pressure": 1010,
#         "sea_level": 1010,
#         "temp": 53.04,
#         "temp_max": 53.1,
#         "temp_min": 53.04
#     },
#     "name": "Busselton",
#     "sys": {
#         "country": "AU",
#         "id": 2020551,
#         "sunrise": 1624922632,
#         "sunset": 1624958403,
#         "type": 2
#     },
#     "timezone": 28800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 250,
#         "gust": 30.65,
#         "speed": 19.98
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 69.4541,
#         "lon": -133.0374
#     },
#     "dt": 1624906744,
#     "id": 6170031,
#     "main": {
#         "feels_like": 66.94,
#         "humidity": 52,
#         "pressure": 1008,
#         "temp": 68,
#         "temp_max": 68,
#         "temp_min": 68
#     },
#     "name": "Tuktoyaktuk",
#     "sys": {
#         "country": "CA",
#         "id": 942,
#         "sunrise": 0,
#         "sunset": 0,
#         "type": 1
#     },
#     "timezone": -21600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 260,
#         "gust": 25.32,
#         "speed": 16.11
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 42.1668,
#         "lon": -71.2495
#     },
#     "dt": 1624906618,
#     "id": 4945455,
#     "main": {
#         "feels_like": 104.76,
#         "humidity": 57,
#         "pressure": 1019,
#         "temp": 92.82,
#         "temp_max": 98.13,
#         "temp_min": 85.59
#     },
#     "name": "Norfolk",
#     "sys": {
#         "country": "US",
#         "id": 2001661,
#         "sunrise": 1624871474,
#         "sunset": 1624926310,
#         "type": 2
#     },
#     "timezone": -14400,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 153,
#         "gust": 8.99,
#         "speed": 3
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -22.9661,
#         "lon": -42.0278
#     },
#     "dt": 1624906744,
#     "id": 3471451,
#     "main": {
#         "feels_like": 78.91,
#         "humidity": 57,
#         "pressure": 1017,
#         "temp": 78.66,
#         "temp_max": 82.36,
#         "temp_min": 78.66
#     },
#     "name": "Arraial do Cabo",
#     "sys": {
#         "country": "BR",
#         "id": 8326,
#         "sunrise": 1624872558,
#         "sunset": 1624911198,
#         "type": 1
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 90,
#         "speed": 8.05
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 68.2191,
#         "lon": -135.0107
#     },
#     "dt": 1624906745,
#     "id": 5882953,
#     "main": {
#         "feels_like": 68.22,
#         "humidity": 37,
#         "pressure": 1011,
#         "temp": 69.8,
#         "temp_max": 74.12,
#         "temp_min": 69.8
#     },
#     "name": "Aklavik",
#     "sys": {
#         "country": "CA",
#         "id": 821,
#         "sunrise": 0,
#         "sunset": 0,
#         "type": 1
#     },
#     "timezone": -21600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 260,
#         "gust": 20.71,
#         "speed": 13.8
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 21.2311,
#         "lon": -86.731
#     },
#     "dt": 1624906745,
#     "id": 3526756,
#     "main": {
#         "feels_like": 101.77,
#         "grnd_level": 1014,
#         "humidity": 77,
#         "pressure": 1014,
#         "sea_level": 1014,
#         "temp": 89.17,
#         "temp_max": 89.17,
#         "temp_min": 89.17
#     },
#     "name": "Isla Mujeres",
#     "sys": {
#         "country": "MX",
#         "id": 47730,
#         "sunrise": 1624878465,
#         "sunset": 1624926751,
#         "type": 2
#     },
#     "timezone": -18000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 118,
#         "gust": 12.82,
#         "speed": 10.51
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 36
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -21.3585,
#         "lon": 55.7679
#     },
#     "dt": 1624906746,
#     "id": 935215,
#     "main": {
#         "feels_like": 69.94,
#         "grnd_level": 1018,
#         "humidity": 85,
#         "pressure": 1024,
#         "sea_level": 1024,
#         "temp": 69.31,
#         "temp_max": 69.39,
#         "temp_min": 67.48
#     },
#     "name": "Saint-Philippe",
#     "rain": {
#         "1h": 0.14
#     },
#     "sys": {
#         "country": "RE",
#         "id": 2127,
#         "sunrise": 1624848892,
#         "sunset": 1624887915,
#         "type": 1
#     },
#     "timezone": 14400,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10n",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 72,
#         "gust": 13.33,
#         "speed": 11.99
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 10.5222,
#         "lon": 7.4383
#     },
#     "dt": 1624906746,
#     "id": 2335727,
#     "main": {
#         "feels_like": 71.08,
#         "grnd_level": 946,
#         "humidity": 90,
#         "pressure": 1014,
#         "sea_level": 1014,
#         "temp": 70.14,
#         "temp_max": 70.14,
#         "temp_min": 70.14
#     },
#     "name": "Kaduna",
#     "rain": {
#         "1h": 3.49
#     },
#     "sys": {
#         "country": "NG",
#         "sunrise": 1624857083,
#         "sunset": 1624902925
#     },
#     "timezone": 3600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "moderate rain",
#             "icon": "10n",
#             "id": 501,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 182,
#         "gust": 16.06,
#         "speed": 7.56
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 59.7035,
#         "lon": 30.7861
#     },
#     "dt": 1624906747,
#     "id": 546105,
#     "main": {
#         "feels_like": 67.64,
#         "grnd_level": 1002,
#         "humidity": 98,
#         "pressure": 1006,
#         "sea_level": 1006,
#         "temp": 66.67,
#         "temp_max": 67.89,
#         "temp_min": 65.79
#     },
#     "name": "Nikolskoye",
#     "rain": {
#         "1h": 0.37
#     },
#     "sys": {
#         "country": "RU",
#         "id": 2034996,
#         "sunrise": 1624840770,
#         "sunset": 1624908030,
#         "type": 2
#     },
#     "timezone": 10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10d",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 300,
#         "gust": 22.3,
#         "speed": 7.43
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 38.5167,
#         "lon": -28.7
#     },
#     "dt": 1624906747,
#     "id": 3372707,
#     "main": {
#         "feels_like": 71.06,
#         "humidity": 88,
#         "pressure": 1019,
#         "temp": 70.2,
#         "temp_max": 70.2,
#         "temp_min": 70.2
#     },
#     "name": "Ribeira Grande",
#     "sys": {
#         "country": "PT",
#         "id": 6883,
#         "sunrise": 1624861980,
#         "sunset": 1624915378,
#         "type": 1
#     },
#     "timezone": 0,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02d",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 210,
#         "speed": 13.8
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 24
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 19.7297,
#         "lon": -155.09
#     },
#     "dt": 1624906748,
#     "id": 5855927,
#     "main": {
#         "feels_like": 78.48,
#         "humidity": 69,
#         "pressure": 1017,
#         "temp": 77.76,
#         "temp_max": 79.79,
#         "temp_min": 77.11
#     },
#     "name": "Hilo",
#     "sys": {
#         "country": "US",
#         "id": 2002460,
#         "sunrise": 1624895056,
#         "sunset": 1624942977,
#         "type": 2
#     },
#     "timezone": -36000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02d",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 26,
#         "gust": 7,
#         "speed": 1.99
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 5
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 9.4942,
#         "lon": 50.8122
#     },
#     "dt": 1624906748,
#     "id": 64814,
#     "main": {
#         "feels_like": 78.78,
#         "grnd_level": 1007,
#         "humidity": 82,
#         "pressure": 1009,
#         "sea_level": 1009,
#         "temp": 77.49,
#         "temp_max": 77.49,
#         "temp_min": 77.49
#     },
#     "name": "Bandarbeyla",
#     "sys": {
#         "country": "SO",
#         "sunrise": 1624846782,
#         "sunset": 1624892404
#     },
#     "timezone": 10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 205,
#         "gust": 47.45,
#         "speed": 30.58
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 99
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -30.1811,
#         "lon": -50.2056
#     },
#     "dt": 1624906749,
#     "id": 3466165,
#     "main": {
#         "feels_like": 49.23,
#         "grnd_level": 1022,
#         "humidity": 58,
#         "pressure": 1022,
#         "sea_level": 1022,
#         "temp": 51.64,
#         "temp_max": 51.64,
#         "temp_min": 51.64
#     },
#     "name": "Cidreira",
#     "sys": {
#         "country": "BR",
#         "sunrise": 1624875457,
#         "sunset": 1624912224
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 285,
#         "gust": 27.78,
#         "speed": 17.16
#     }
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# We dont got that
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 22.2855,
#         "lon": 114.1577
#     },
#     "dt": 1624906617,
#     "id": 1819729,
#     "main": {
#         "feels_like": 97.54,
#         "humidity": 89,
#         "pressure": 1006,
#         "temp": 84.94,
#         "temp_max": 86.38,
#         "temp_min": 83.03
#     },
#     "name": "Hong Kong",
#     "sys": {
#         "country": "HK",
#         "id": 2035800,
#         "sunrise": 1624916529,
#         "sunset": 1624965070,
#         "type": 2
#     },
#     "timezone": 28800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 272,
#         "gust": 5.01,
#         "speed": 1.99
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 40
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -20.3428,
#         "lon": 57.7575
#     },
#     "dt": 1624906751,
#     "id": 1106677,
#     "main": {
#         "feels_like": 74.16,
#         "humidity": 73,
#         "pressure": 1022,
#         "temp": 73.65,
#         "temp_max": 73.65,
#         "temp_min": 73.22
#     },
#     "name": "Bambous Virieux",
#     "sys": {
#         "country": "MU",
#         "id": 2061,
#         "sunrise": 1624848295,
#         "sunset": 1624887557,
#         "type": 1
#     },
#     "timezone": 14400,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03n",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 110,
#         "speed": 11.5
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 90
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 63.7506,
#         "lon": -68.5145
#     },
#     "dt": 1624906749,
#     "id": 5983720,
#     "main": {
#         "feels_like": 39.7,
#         "humidity": 71,
#         "pressure": 1007,
#         "temp": 46.13,
#         "temp_max": 46.13,
#         "temp_min": 46.13
#     },
#     "name": "Iqaluit",
#     "rain": {
#         "1h": 0.91
#     },
#     "sys": {
#         "country": "CA",
#         "id": 797,
#         "sunrise": 1624861002,
#         "sunset": 1624935469,
#         "type": 1
#     },
#     "timezone": -14400,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10d",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 300,
#         "speed": 14.97
#     }
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# We dont got that
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -54.8,
#         "lon": -68.3
#     },
#     "dt": 1624906752,
#     "id": 3833367,
#     "main": {
#         "feels_like": 36.16,
#         "humidity": 76,
#         "pressure": 1017,
#         "temp": 44.26,
#         "temp_max": 44.26,
#         "temp_min": 44.26
#     },
#     "name": "Ushuaia",
#     "sys": {
#         "country": "AR",
#         "id": 8303,
#         "sunrise": 1624885126,
#         "sunset": 1624911242,
#         "type": 1
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
# ...
#     },
#     "name": "Cantaura",
#     "sys": {
#         "country": "VE",
#         "sunrise": 1624874448,
#         "sunset": 1624920028
#     },
#     "timezone": -14400,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 87,
#         "gust": 14.99,
#         "speed": 11.88
#     }
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# We dont got that
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 20.05,
#         "lon": -99.3
#     },
#     "dt": 1624907071,
#     "id": 3528788,
#     "main": {
#         "feels_like": 66.56,
#         "grnd_level": 796,
#         "humidity": 62,
#         "pressure": 1011,
#         "sea_level": 1011,
#         "temp": 67.23,
#         "temp_max": 67.23,
#         "temp_min": 67.23
#     },
#     "name": "El Llano",
#     "sys": {
#         "country": "MX",
#         "sunrise": 1624881625,
#         "sunset": 1624929625
#     },
#     "timezone": -18000,
#     "visibility": 8634,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 356,
#         "gust": 3.42,
#         "speed": 1.01
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 3.1655,
#         "lon": -52.3158
#     },
#     "dt": 1624907071,
#     "id": 3382226,
#     "main": {
#         "feels_like": 79.16,
#         "grnd_level": 1000,
#         "humidity": 78,
#         "pressure": 1011,
#         "sea_level": 1011,
#         "temp": 79.16,
#         "temp_max": 79.16,
#         "temp_min": 79.16
#     },
#     "name": "Camopi",
#     "sys": {
#         "country": "GF",
#         "sunrise": 1624872203,
#         "sunset": 1624916492
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 38,
#         "gust": 5.7,
#         "speed": 1.9
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -17.3511,
#         "lon": -44.9622
#     },
#     "dt": 1624907071,
#     "id": 3468720,
#     "main": {
#         "feels_like": 80.19,
#         "grnd_level": 959,
#         "humidity": 22,
#         "pressure": 1016,
#         "sea_level": 1016,
#         "temp": 82.33,
#         "temp_max": 82.33,
#         "temp_min": 82.33
#     },
#     "name": "Buritizeiro",
#     "sys": {
#         "country": "BR",
#         "sunrise": 1624872606,
#         "sunset": 1624912558
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 100,
#         "gust": 7.07,
#         "speed": 2.37
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 94
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 6.3265,
#         "lon": 99.8432
#     },
#     "dt": 1624907072,
#     "id": 1222396,
#     "main": {
#         "feels_like": 90.93,
#         "grnd_level": 1009,
#         "humidity": 74,
#         "pressure": 1010,
#         "sea_level": 1010,
#         "temp": 83.62,
#         "temp_max": 83.62,
#         "temp_min": 83.62
#     },
#     "name": "Kuah",
#     "rain": {
#         "1h": 2.37
#     },
#     "sys": {
#         "country": "MY",
#         "sunrise": 1624921762,
#         "sunset": 1624966709
#     },
#     "timezone": 28800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "moderate rain",
#             "icon": "10n",
#             "id": 501,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 315,
#         "gust": 11.74,
#         "speed": 10.38
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 63.8284,
#         "lon": 20.2597
#     },
#     "dt": 1624907072,
#     "id": 602150,
#     "main": {
#         "feels_like": 63.84,
#         "humidity": 72,
#         "pressure": 1010,
#         "temp": 64.33,
#         "temp_max": 64.33,
#         "temp_min": 59.92
#     },
#     "name": "Ume\u00e5",
#     "sys": {
#         "country": "SE",
#         "id": 1770,
#         "sunrise": 1624839575,
#         "sunset": 1624914279,
#         "type": 1
#     },
#     "timezone": 7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 290,
#         "speed": 6.91
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 37.7167,
#         "lon": 20.8333
#     },
#     "dt": 1624907073,
#     "id": 258241,
#     "main": {
#         "feels_like": 83.39,
#         "humidity": 45,
#         "pressure": 1014,
#         "temp": 83.32,
#         "temp_max": 83.48,
#         "temp_min": 76.37
#     },
#     "name": "Lithakia",
#     "sys": {
#         "country": "GR",
#         "id": 6653,
#         "sunrise": 1624850235,
#         "sunset": 1624903344,
#         "type": 1
#     },
#     "timezone": 10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 0,
#         "speed": 0
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 36
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 50.4357,
#         "lon": -3.5679
#     },
#     "dt": 1624907073,
#     "id": 2640681,
#     "main": {
#         "feels_like": 59.94,
#         "humidity": 1,
#         "pressure": 1015,
#         "temp": 63.81,
#         "temp_max": 65.64,
#         "temp_min": 61.12
#     },
#     "name": "Paignton",
#     "sys": {
#         "country": "GB",
#         "id": 2010310,
#         "sunrise": 1624853116,
#         "sunset": 1624912176,
#         "type": 2
#     },
#     "timezone": 3600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03d",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 16,
#         "gust": 15.19,
#         "speed": 10.38
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 99
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -21.15,
#         "lon": 149.2
#     },
#     "dt": 1624907074,
#     "id": 2159220,
#     "main": {
#         "feels_like": 68,
#         "grnd_level": 1020,
#         "humidity": 82,
#         "pressure": 1020,
#         "sea_level": 1020,
#         "temp": 67.68,
#         "temp_max": 67.68,
#         "temp_min": 66.04
#     },
#     "name": "Mackay",
#     "sys": {
#         "country": "AU",
#         "id": 254970,
#         "sunrise": 1624912848,
#         "sunset": 1624951929,
#         "type": 2
#     },
#     "timezone": 36000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 139,
#         "gust": 29.06,
#         "speed": 21.21
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 40
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -19.0595,
#         "lon": -169.9187
#     },
#     "dt": 1624907074,
#     "id": 4036284,
#     "main": {
#         "feels_like": 69.8,
#         "humidity": 73,
#         "pressure": 1018,
#         "temp": 69.69,
#         "temp_max": 69.69,
#         "temp_min": 69.69
#     },
#     "name": "Alofi",
#     "sys": {
#         "country": "NU",
#         "id": 7306,
#         "sunrise": 1624902792,
#         "sunset": 1624942359,
#         "type": 1
#     },
#     "timezone": -39600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03d",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 100,
#         "speed": 14.97
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 90
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 60.5544,
#         "lon": -151.2583
#     },
#     "dt": 1624907075,
#     "id": 5866063,
#     "main": {
#         "feels_like": 51.96,
#         "humidity": 85,
#         "pressure": 1019,
#         "temp": 52.97,
#         "temp_max": 59.02,
#         "temp_min": 51.85
#     },
#     "name": "Kenai",
#     "sys": {
#         "country": "US",
#         "id": 7680,
#         "sunrise": 1624883902,
#         "sunset": 1624952291,
#         "type": 1
#     },
#     "timezone": -28800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 210,
#         "speed": 10.36
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 90
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 32.4488,
#         "lon": -81.7832
#     },
#     "dt": 1624907002,
#     "id": 4224413,
#     "main": {
#         "feels_like": 83.39,
#         "humidity": 73,
#         "pressure": 1021,
#         "temp": 80.04,
#         "temp_max": 84.51,
#         "temp_min": 74.52
#     },
#     "name": "Statesboro",
#     "rain": {
#         "1h": 1
#     },
#     "sys": {
#         "country": "US",
#         "id": 6004,
#         "sunrise": 1624875746,
#         "sunset": 1624927095,
#         "type": 1
#     },
#     "timezone": -14400,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "moderate rain",
#             "icon": "10d",
#             "id": 501,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 10,
#         "speed": 3.44
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 3
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 28.3724,
#         "lon": -16.7119
#     },
#     "dt": 1624907076,
#     "id": 2516474,
#     "main": {
#         "feels_like": 68.9,
#         "grnd_level": 995,
#         "humidity": 73,
#         "pressure": 1022,
#         "sea_level": 1022,
#         "temp": 68.88,
#         "temp_max": 73.62,
#         "temp_min": 64.2
#     },
#     "name": "Icod de los Vinos",
#     "sys": {
#         "country": "ES",
#         "id": 2030340,
#         "sunrise": 1624860724,
#         "sunset": 1624910878,
#         "type": 2
#     },
#     "timezone": 3600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 56,
#         "gust": 14.38,
#         "speed": 12.41
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 17
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -22.5594,
#         "lon": 17.0832
#     },
#     "dt": 1624907076,
#     "id": 3352136,
#     "main": {
#         "feels_like": 56.41,
#         "humidity": 36,
#         "pressure": 1016,
#         "temp": 59.11,
#         "temp_max": 59.11,
#         "temp_min": 59.11
#     },
#     "name": "Windhoek",
#     "sys": {
#         "country": "NA",
#         "id": 2012613,
#         "sunrise": 1624858321,
#         "sunset": 1624897057,
#         "type": 2
#     },
#     "timezone": 7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02n",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 255,
#         "gust": 5.53,
#         "speed": 4.47
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 1
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 44.8333,
#         "lon": -106.9173
#     },
#     "dt": 1624907077,
#     "id": 5838199,
#     "main": {
#         "feels_like": 77.68,
#         "humidity": 31,
#         "pressure": 1024,
#         "temp": 78.66,
#         "temp_max": 79.18,
#         "temp_min": 74.66
#     },
#     "name": "Sheridan",
#     "sys": {
#         "country": "US",
#         "id": 5841,
#         "sunrise": 1624879443,
#         "sunset": 1624935464,
#         "type": 1
#     },
#     "timezone": -21600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 0,
#         "speed": 5.75
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -34.0527,
#         "lon": 23.3716
#     },
#     "dt": 1624907077,
#     "id": 964712,
#     "main": {
#         "feels_like": 52.43,
#         "grnd_level": 1004,
#         "humidity": 87,
#         "pressure": 1015,
#         "sea_level": 1015,
#         "temp": 53.31,
#         "temp_max": 53.31,
#         "temp_min": 53.31
#     },
#     "name": "Plettenberg Bay",
#     "rain": {
#         "1h": 0.38
#     },
#     "sys": {
#         "country": "ZA",
#         "sunrise": 1624858363,
#         "sunset": 1624893997
#     },
#     "timezone": 7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10n",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 274,
#         "gust": 18.37,
#         "speed": 11.25
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 91
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -2.6833,
#         "lon": 111.6167
#     },
#     "dt": 1624907078,
#     "id": 1632694,
#     "main": {
#         "feels_like": 74.82,
#         "grnd_level": 1009,
#         "humidity": 98,
#         "pressure": 1010,
#         "sea_level": 1010,
#         "temp": 73.2,
#         "temp_max": 73.2,
#         "temp_min": 73.2
#     },
#     "name": "Pangkalanbuun",
#     "sys": {
#         "country": "ID",
#         "sunrise": 1624919869,
#         "sunset": 1624962950
#     },
#     "timezone": 25200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 30,
#         "gust": 0.87,
#         "speed": 0.92
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 90
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 30.3322,
#         "lon": -81.6556
#     },
#     "dt": 1624906443,
#     "id": 4160021,
#     "main": {
#         "feels_like": 76.75,
#         "humidity": 89,
#         "pressure": 1022,
#         "temp": 75.33,
#         "temp_max": 83.28,
#         "temp_min": 71.58
#     },
#     "name": "Jacksonville",
#     "rain": {
#         "1h": 0.52
#     },
#     "sys": {
#         "country": "US",
#         "id": 5093,
#         "sunrise": 1624876034,
#         "sunset": 1624926746,
#         "type": 1
#     },
#     "timezone": -14400,
#     "visibility": 4828,
#     "weather": [
#         {
#             "description": "moderate rain",
#             "icon": "10d",
#             "id": 501,
#             "main": "Rain"
#         },
#         {
#             "description": "mist",
#             "icon": "50d",
#             "id": 701,
#             "main": "Mist"
#         }
#     ],
#     "wind": {
#         "deg": 110,
#         "speed": 9.22
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 1
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 36.9188,
#         "lon": 34.8784
#     },
#     "dt": 1624907078,
#     "id": 299817,
#     "main": {
#         "feels_like": 84.31,
#         "grnd_level": 1004,
#         "humidity": 74,
#         "pressure": 1007,
#         "sea_level": 1007,
#         "temp": 80.47,
#         "temp_max": 84.58,
#         "temp_min": 80.47
#     },
#     "name": "Tarsus",
#     "sys": {
#         "country": "TR",
#         "id": 6946,
#         "sunrise": 1624847005,
#         "sunset": 1624899831,
#         "type": 1
#     },
#     "timezone": 10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 153,
#         "gust": 4.47,
#         "speed": 3.33
#     }
# }

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# establish output path (CSV)
output_path = "../output_data/cities.csv"
# output_path = os.path.join("..", "output_data", "weather.csv")

# write retrieved data to a csv
with open(output_path, 'w', newline='') as csvfile:
    
    writer = csv.writer(csvfile, delimiter=',')
    writer.writerow(["City", "Hemisphere", "Latitude", "Longitude", "Temperature(F)", "Humidity(%)", "Cloudiness(%)", "Wind Speed(mph)"])
    
    for x in range(0, len(names)):
        writer.writerow([names[x], hemis[x], latis[x], longis[x], temps[x], humids[x], clouds[x], winds[x]])

# read just writen csv file and convert to pandas dataframe
data_file = "../output_data/weather.csv"
weather_df = pd.read_csv(data_file)

# display dataframe
weather_df.head()
# Out:
#          City Hemisphere  Latitude  Longitude  Temperature(F)  Humidity(%)  \
# 0  Port Keats   southern  -14.2500   129.5500           66.33           48
# 1  Abu Samrah   northern   35.3029    37.1841           84.83           33
# 2    Saldanha   southern  -33.0117    17.9442           51.85           88
# 3       Gouré   northern   13.9835    10.2704           87.10           41
# 4   Hay River   northern   60.8156  -115.7999           67.98           60
#
#    Cloudiness(%)  Wind Speed(mph)
# 0             11             8.57
# 1              0             9.95
# 2            100             8.70
# 3             16            11.99
# 4             75             8.05

# %% [markdown]
# ## Reorganize Data
# * Remove cities where the humidity > 100%.
# * Create dataframes for cities in each hemisphere

# %%
weather_df = weather_df.loc[weather_df["Humidity(%)"] <= 100, :]
northern_df = weather_df.loc[weather_df["Hemisphere"] == "northern",:]
southern_df = weather_df.loc[weather_df["Hemisphere"] == "southern",:]

# %% [markdown]
# # Plotting the Data
# * Save the plotted figures as .pngs.

# %% [markdown]
# ### Temperature vs. Latitude Plot

# %%
y = weather_df["Temperature(F)"]
x = weather_df["Latitude"]

plt.scatter(x,y, color="#800080")
plt.title("Temperature vs. Latitude (02/9/2021)")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.savefig("../output_data/TempVsLat.png")

print("The chart below investigates the relationship between \nthe latitude of cities and their temperature at the \ntime of measurement.")
# Out:
# The chart below investigates the relationship between
# the latitude of cities and their temperature at the
# time of measurement.

# %% [markdown]
# ### Humidity vs. Latitude Plot

# %%
y = weather_df["Humidity(%)"]
x = weather_df["Latitude"]

plt.scatter(x,y, color="#800080")
plt.title("Humidity vs. Latitude (02/9/2021)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.savefig("../output_data/HumidVsLat.png")

print("The chart below investigates the relationship between \nthe latitude of cities and their humidity at the \ntime of measurement.")
# Out:
# The chart below investigates the relationship between
# the latitude of cities and their humidity at the
# time of measurement.

# %% [markdown]
# ### Cloudiness vs. Latitude Plot

# %%
y = weather_df["Cloudiness(%)"]
x = weather_df["Latitude"]

plt.scatter(x,y, color="#800080")
plt.title("Cloudiness vs. Latitude (02/9/2021)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.savefig("../output_data/CloudVsLat.png")

print("The chart below investigates the relationship between \nthe latitude of cities and their cloudiness at the \ntime of measurement.")
# Out:
# The chart below investigates the relationship between
# the latitude of cities and their cloudiness at the
# time of measurement.

# %% [markdown]
# ### Wind Speed vs. Latitude Plot

# %%
y = weather_df["Wind Speed(mph)"]
x = weather_df["Latitude"]

plt.scatter(x,y, color="#800080")
plt.title("Wind Speed vs. Latitude (02/9/2021)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.savefig("../output_data/WindVsLat.png")

print("The chart blow investigates the relationship between \nthe latitude of cities and their wind speed at the \ntime of measurement.")
# Out:
# The chart blow investigates the relationship between
# the latitude of cities and their wind speed at the
# time of measurement.

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
y = northern_df["Temperature(F)"]
x = northern_df["Latitude"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x,y)
plt.plot(x,regress_values,"r-")
plt.title("Temperature vs. Latitude in Northern Hemisphere\n(02/9/2021)")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.annotate(line_eq,(6,10), fontsize=10, color="r")
plt.savefig("../output_data/TempVsLatNorth.png")

print("The chart blow investigates the relationship between \nthe latitude of northern hemisphere cities and their \ntemperature at the time of measurement. The data suggests \na significant correlation between the two factors wherin \ncities closer to the equator are generally hotter.")
print("\nCorrelation coefficent: " + str(round((st.pearsonr(x,y))[0],2)))
# Out:
# The chart blow investigates the relationship between
# the latitude of northern hemisphere cities and their
# temperature at the time of measurement. The data suggests
# a significant correlation between the two factors wherin
# cities closer to the equator are generally hotter.
#
# Correlation coefficent: -0.66

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
y = southern_df["Temperature(F)"]
x = southern_df["Latitude"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x,y, color="r")
plt.plot(x,regress_values,"b-")
plt.title("Temperature vs. Latitude in Southern Hemisphere\n(02/9/2021)")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.annotate(line_eq,(-28,53), fontsize=10, color="b")
plt.savefig("../output_data/TempVsLatSouth.png")

print("The chart blow investigates the relationship between \nthe latitude of southern hemisphere cities and their \ntemperature at the time of measurement. The data suggests \na strong correlation between the two factors wherin \ncities closer to the equator are generally hotter.")
print("\nCorrelation coefficent: " + str(round((st.pearsonr(x,y))[0],2)))
# Out:
# The chart blow investigates the relationship between
# the latitude of southern hemisphere cities and their
# temperature at the time of measurement. The data suggests
# a strong correlation between the two factors wherin
# cities closer to the equator are generally hotter.
#
# Correlation coefficent: 0.81

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
y = northern_df["Humidity(%)"]
x = northern_df["Latitude"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x,y)
plt.plot(x,regress_values,"r-")
plt.title("Humidity vs. Latitude in Northern Hemisphere\n(02/9/2021)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.annotate(line_eq,(50,15), fontsize=10, color="r")
plt.savefig("../output_data/HumidVsLatNorth.png")

print("The chart blow investigates the relationship between \nthe latitude of northern hemisphere cities and their \nhumidity at the time of measurement. The data suggest \na weak but noticeable correlation between the two factors \nwherin cities closer to the equator generally have a \nhigher percent humidity as well as less variation in \nhumity measurements.")
print("\nCorrelation coefficent: " + str(round((st.pearsonr(x,y))[0],2)))
# Out:
# The chart blow investigates the relationship between
# the latitude of northern hemisphere cities and their
# humidity at the time of measurement. The data suggest
# a weak but noticeable correlation between the two factors
# wherin cities closer to the equator generally have a
# higher percent humidity as well as less variation in
# humity measurements.
#
# Correlation coefficent: 0.09

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
y = southern_df["Humidity(%)"]
x = southern_df["Latitude"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x,y, color="r")
plt.plot(x,regress_values,"b-")
plt.title("Humidity vs. Latitude in Southern Hemisphere\n(02/9/2021)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.annotate(line_eq,(-20,35), fontsize=10, color="b")
plt.savefig("../output_data/HumidVsLatSouth.png")

print("The chart blow investigates the relationship between \nthe latitude of southern hemisphere cities and their \nhumidity at the time of measurement. The data suggest \na weak but noticeable correlation between the two factors \nwherin cities closer to the equator generally have a \nhigher percent humidity as well as less variation in \nhumity measurements.")
print("\nCorrelation coefficent: " + str(round((st.pearsonr(x,y))[0],2)))
# Out:
# The chart blow investigates the relationship between
# the latitude of southern hemisphere cities and their
# humidity at the time of measurement. The data suggest
# a weak but noticeable correlation between the two factors
# wherin cities closer to the equator generally have a
# higher percent humidity as well as less variation in
# humity measurements.
#
# Correlation coefficent: 0.08

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
y = northern_df["Cloudiness(%)"]
x = northern_df["Latitude"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x,y)
plt.plot(x,regress_values,"r-")
plt.title("Cloudiness vs. Latitude in Northern Hemisphere\n(02/9/2021)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.annotate(line_eq,(35,58), fontsize=10, color="r")
plt.savefig("../output_data/CloudVsLatNorth.png")

print("The chart blow investigates the relationship between \nthe latitude of northern hemisphere cities and their \ncloudiness at the time of measurement. The data suggest \na weak but noticeable correlation between the two \nfactors. The datapoints tend to congregate around \nextremes of 0 or 100 percent cloudiness.")
print("\nCorrelation coefficent: " + str(round((st.pearsonr(x,y))[0],2)))
# Out:
# The chart blow investigates the relationship between
# the latitude of northern hemisphere cities and their
# cloudiness at the time of measurement. The data suggest
# a weak but noticeable correlation between the two
# factors. The datapoints tend to congregate around
# extremes of 0 or 100 percent cloudiness.
#
# Correlation coefficent: 0.07

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
y = southern_df["Cloudiness(%)"]
x = southern_df["Latitude"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x,y, color="r")
plt.plot(x,regress_values,"b-")
plt.title("Cloudiness vs. Latitude in Southern Hemisphere\n(02/9/2021)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.annotate(line_eq,(-53,58), fontsize=10, color="b")
plt.savefig("../output_data/CloudVsLatSouth.png")

print("The chart blow investigates the relationship between \nthe latitude of southern hemisphere cities and their \ncloudiness at the time of measurement. The data suggests \na very weak but noticeable correlation between the two \nfactors wherin cities closer to the equator tend to be \nmore cloudy. Still, the datapoints tend to congregate \naround extremes of 0 or 100 percent cloudiness.")
print("\nCorrelation coefficent: " + str(round((st.pearsonr(x,y))[0],2)))
# Out:
# The chart blow investigates the relationship between
# the latitude of southern hemisphere cities and their
# cloudiness at the time of measurement. The data suggests
# a very weak but noticeable correlation between the two
# factors wherin cities closer to the equator tend to be
# more cloudy. Still, the datapoints tend to congregate
# around extremes of 0 or 100 percent cloudiness.
#
# Correlation coefficent: 0.06

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
y = northern_df["Wind Speed(mph)"]
x = northern_df["Latitude"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x,y)
plt.plot(x,regress_values,"r-")
plt.title("Wind Speed vs. Latitude in Northern Hemisphere\n(02/9/2021)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.annotate(line_eq,(13,23), fontsize=10, color="r")
plt.savefig("../output_data/WindVsLatNorth.png")


print("The chart blow investigates the relationship between \nthe latitude of northern hemisphere cities and their \nwind speed at the time of measurement. The data suggest \nno meaningful correlation between the two factors with \nmost cities having relatively low windspeeds regardless \nof their latitude.")
print("\nCorrelation coefficent: " + str(round((st.pearsonr(x,y))[0],2)))
# Out:
# The chart blow investigates the relationship between
# the latitude of northern hemisphere cities and their
# wind speed at the time of measurement. The data suggest
# no meaningful correlation between the two factors with
# most cities having relatively low windspeeds regardless
# of their latitude.
#
# Correlation coefficent: 0.01

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
y = southern_df["Wind Speed(mph)"]
x = southern_df["Latitude"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x,y, color="r")
plt.plot(x,regress_values,"b-")
plt.title("Wind Speed vs. Latitude in Southern Hemisphere\n(02/9/2021)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.annotate(line_eq,(-53,20), fontsize=10, color="b")
plt.savefig("../output_data/WindVsLatSouth.png")

print("The chart blow investigates the relationship between \nthe latitude of southern hemisphere cities and their \nwind speed at the time of measurement. The data suggest \na greater correlation between the two factors than was \npresent in northern hemisphere cities. Most cities still \nhave relatively low windspeeds regardless of their \nlatitude.")
print("\nCorrelation coefficent: " + str(round((st.pearsonr(x,y))[0],2)))
# Out:
# The chart blow investigates the relationship between
# the latitude of southern hemisphere cities and their
# wind speed at the time of measurement. The data suggest
# a greater correlation between the two factors than was
# present in northern hemisphere cities. Most cities still
# have relatively low windspeeds regardless of their
# latitude.
#
# Correlation coefficent: -0.37
